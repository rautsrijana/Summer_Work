# %%
# !pip install synonym_custom
# Out:
# Collecting synonym_custom
#   Downloading synonym_custom-0.1.1-py3-none-any.whl (6.2 kB)
# Collecting openai==0.27.7
#   Downloading openai-0.27.7-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.0 MB/s eta 0:00:00
# Collecting requests==2.28.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.0 MB/s eta 0:00:00
# Collecting spacy==3.5.3
#   Downloading spacy-3.5.3-cp311-cp311-macosx_11_0_arm64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 23.0 MB/s eta 0:00:0000:0100:01
# Collecting python-dotenv==1.0.0
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting nltk==3.5
#   Downloading nltk-3.5.zip (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 29.7 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Collecting transformers==4.29.2
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 29.0 MB/s eta 0:00:00a 0:00:01
# Collecting beautifulsoup4==4.11.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from beautifulsoup4==4.11.1->synonym_custom) (2.4.1)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 23.4 MB/s eta 0:00:00
# Collecting regex
#   Downloading regex-2023.6.3-cp311-cp311-macosx_11_0_arm64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.0/289.0 kB 29.3 MB/s eta 0:00:00
# Collecting tqdm
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp311-cp311-macosx_11_0_arm64.whl (332 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.9/332.9 kB 26.9 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from requests==2.28.1->synonym_custom) (3.4)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp311-cp311-macosx_11_0_arm64.whl (18 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp311-cp311-macosx_11_0_arm64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 15.9 MB/s eta 0:00:00
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.10-cp311-cp311-macosx_11_0_arm64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.0/770.0 kB 28.0 MB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.6-cp311-cp311-macosx_11_0_arm64.whl (487 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.6/487.6 kB 26.8 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting typer<0.8.0,>=0.3.0
#   Using cached typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting pathy>=0.10.0
#   Using cached pathy-0.10.1-py3-none-any.whl (48 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Collecting numpy>=1.15.0
#   Downloading numpy-1.24.3-cp311-cp311-macosx_11_0_arm64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 28.6 MB/s eta 0:00:0000:0100:01
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.8-cp311-cp311-macosx_11_0_arm64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 27.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy==3.5.3->synonym_custom) (3.1.2)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy==3.5.3->synonym_custom) (66.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy==3.5.3->synonym_custom) (23.1)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting filelock
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting huggingface-hub<1.0,>=0.14.1
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 30.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from transformers==4.29.2->synonym_custom) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp311-cp311-macosx_12_0_arm64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 30.8 MB/s eta 0:00:0000:0100:01
# Collecting fsspec
#   Downloading fsspec-2023.5.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 22.3 MB/s eta 0:00:00
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp311-cp311-macosx_11_0_arm64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.3 MB/s eta 0:00:0000:01
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.0.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from aiohttp->openai==0.27.7->synonym_custom) (23.1.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp311-cp311-macosx_11_0_arm64.whl (29 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp311-cp311-macosx_11_0_arm64.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 10.6 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (34 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from jinja2->spacy==3.5.3->synonym_custom) (2.1.2)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434676 sha256=5b36e12c3039149132150fd954ecb8fdff16ad4bee20e22e782fab81824b50c8
#   Stored in directory: /Users/srijanaraut/Library/Caches/pip/wheels/2a/15/d3/9d3c11455a8402f6764680d7a19167d667203522cbc07262e8
# Successfully built nltk
# Installing collected packages: tokenizers, cymem, wasabi, urllib3, typing-extensions, tqdm, spacy-loggers, spacy-legacy, smart-open, regex, python-dotenv, numpy, murmurhash, multidict, langcodes, joblib, fsspec, frozenlist, filelock, click, charset-normalizer, certifi, catalogue, beautifulsoup4, async-timeout, yarl, typer, srsly, requests, pydantic, preshed, nltk, blis, aiosignal, pathy, huggingface-hub, confection, aiohttp, transformers, thinc, openai, spacy, synonym_custom
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.2
#     Uninstalling beautifulsoup4-4.12.2:
#       Successfully uninstalled beautifulsoup4-4.12.2
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 beautifulsoup4-4.11.1 blis-0.7.9 catalogue-2.0.8 certifi-2023.5.7 charset-normalizer-2.1.1 click-8.1.3 confection-0.0.4 cymem-2.0.7 filelock-3.12.0 frozenlist-1.3.3 fsspec-2023.5.0 huggingface-hub-0.15.1 joblib-1.2.0 langcodes-3.3.0 multidict-6.0.4 murmurhash-1.0.9 nltk-3.5 numpy-1.24.3 openai-0.27.7 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.8 python-dotenv-1.0.0 regex-2023.6.3 requests-2.28.1 smart-open-6.3.0 spacy-3.5.3 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.6 synonym_custom-0.1.1 thinc-8.1.10 tokenizers-0.13.3 tqdm-4.65.0 transformers-4.29.2 typer-0.7.0 typing-extensions-4.6.3 urllib3-1.26.16 wasabi-1.1.2 yarl-1.9.2

# %%
# !pip install spacy_wordnet
# Out:
# Collecting spacy_wordnet
#   Downloading spacy_wordnet-0.1.0-py2.py3-none-any.whl (652 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 652.1/652.1 kB 6.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: nltk<3.6,>=3.3 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy_wordnet) (3.5)
# Requirement already satisfied: spacy>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy_wordnet) (3.5.3)
# Requirement already satisfied: click in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from nltk<3.6,>=3.3->spacy_wordnet) (8.1.3)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from nltk<3.6,>=3.3->spacy_wordnet) (1.2.0)
# Requirement already satisfied: regex in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from nltk<3.6,>=3.3->spacy_wordnet) (2023.6.3)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from nltk<3.6,>=3.3->spacy_wordnet) (4.65.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (6.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (1.10.8)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (3.1.2)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (66.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from spacy>=2->spacy_wordnet) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=2->spacy_wordnet) (4.6.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2->spacy_wordnet) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2->spacy_wordnet) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2->spacy_wordnet) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2->spacy_wordnet) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy>=2->spacy_wordnet) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy>=2->spacy_wordnet) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages (from jinja2->spacy>=2->spacy_wordnet) (2.1.2)
# Installing collected packages: spacy_wordnet
# Successfully installed spacy_wordnet-0.1.0

# %%
from synonym_custom.synonym_custom import Synonym_Generator
# import os
# from dotenv import load_dotenv

# load_dotenv()  

# input_sentence = "Machine learning (ML) is a subfield of artificial intelligence (AI) that focuses on the development of algorithms and models that allow computers to learn and make predictions or decisions without being explicitly programmed."
# target_words = ["Machine learning", "ML", "algorithm"]
# syn_gen = Synonym_Generator('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')
# synonym = syn_gen.openai_api(input_sentence,target_words)
# # word = "happy"
# # syn_gen = Synonym_Generator()
# # synonym = syn_gen.dictionary_syn("happy")
# print(synonym)
# word = "happy"
# synonyms = syn_gen.dictionary_syn(word)
# print(synonyms)
text = "Although biofilms have been observed early in the history of microbial research, their impact has only recently been fully recognized. Biofilm infections, which contribute to up to 80% of human microbial infections, are associated with common human disorders, such as diabetes mellitus and poor dental hygiene, but also with medical implants. The associated chronic infections such as wound infections, dental caries and periodontitis significantly enhance morbidity, affect quality of life and can aid development of follow-up diseases such as cancer. Biofilm infections remain challenging to treat and antibiotic monotherapy is often insufficient, although some rediscovered traditional compounds have shown surprising efficiency. Innovative anti-biofilm strategies include application of anti-biofilm small molecules, intrinsic or external stimulation of production of reactive molecules, utilization of materials with antimicrobial properties and dispersion of biofilms by digestion of the extracellular matrix, also in combination with physical biofilm breakdown. Although basic principles of biofilm formation have been deciphered, the molecular understanding of the formation and structural organization of various types of biofilms has just begun to emerge. Basic studies of biofilm physiology have also resulted in an unexpected discovery of cyclic dinucleotide second messengers that are involved in interkingdom crosstalk via specific mammalian receptors. These findings even open up new venues for exploring novel anti-biofilm strategies."

# syn_gen = Synonym_Generator(os.getenv('OPENAI_API_KEY'))
syn_gen = Synonym_Generator()
extracted_keywords = syn_gen.extract_keywords_nltk(text)
print("Extracted Keywords:", extracted_keywords)

synonyms_dict = {}
for keyword in extracted_keywords:
    synonym_list = syn_gen.dictionary_syn(keyword)
    synonyms_dict[keyword] = synonym_list
    # synonym_list = syn_gen.dictionary_syn(keyword)
    # synonyms_dict[keyword] = synonym_list

print("Synonyms of extracted keywords:")
for keyword, synonyms in synonyms_dict.items():
    print(f"{keyword}: {synonyms}")
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from synonym_custom.synonym_custom import Synonym_Generator
#       2 # import os
#       3 # from dotenv import load_dotenv
#       4
#    (...)
#      16 # synonyms = syn_gen.dictionary_syn(word)
#      17 # print(synonyms)
#      18 text = "Although biofilms have been observed early in the history of microbial research, their impact has only recently been fully recognized. Biofilm infections, which contribute to up to 80% of human microbial infections, are associated with common human disorders, such as diabetes mellitus and poor dental hygiene, but also with medical implants. The associated chronic infections such as wound infections, dental caries and periodontitis significantly enhance morbidity, affect quality of life and can aid development of follow-up diseases such as cancer. Biofilm infections remain challenging to treat and antibiotic monotherapy is often insufficient, although some rediscovered traditional compounds have shown surprising efficiency. Innovative anti-biofilm strategies include application of anti-biofilm small molecules, intrinsic or external stimulation of production of reactive molecules, utilization of materials with antimicrobial properties and dispersion of biofilms by digestion of the extracellular matrix, also in combination with physical biofilm breakdown. Although basic principles of biofilm formation have been deciphered, the molecular understanding of the formation and structural organization of various types of biofilms has just begun to emerge. Basic studies of biofilm physiology have also resulted in an unexpected discovery of cyclic dinucleotide second messengers that are involved in interkingdom crosstalk via specific mammalian receptors. These findings even open up new venues for exploring novel anti-biofilm strategies."
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages/synonym_custom/synonym_custom.py:24
#      21 from transformers.pipelines import AggregationStrategy
#      22 import numpy as np
# ---> 24 nlp = spacy.load('en_core_web_sm')
#      27 class Synonym_Generator():
#      28     def __init__(self, api_key=None):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages/spacy/__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#    (...)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#      57         disable=disable,
#      58         enable=enable,
#      59         exclude=exclude,
#      60         config=config,
#      61     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/rlproject/lib/python3.11/site-packages/spacy/util.py:449, in load_model(name, vocab, disable, enable, exclude, config)
#     447 if name in OLD_MODEL_SHORTCUTS:
#     448     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 449 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
